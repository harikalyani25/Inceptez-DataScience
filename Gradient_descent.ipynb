# %% [markdown]
# #### Step 1: We will initialize slope and Intercept
# #### Step 2: Learning Rate and Iteration
# #### Step 1: Loop iteration
# #### Step 1: Y prediction
# #### Step 1: We will initialize slope and Intercept
#
# #### Step 1: Iitialize the slope and the Intercept values
# #### Step 2: Initializr the Learning Rate and the iterations
# #### Step 3: Loop(iterations):
# #### Step 4: Y_prediction = m*X+c
# #### Step 5: PD value of Slope and Intercept
#         ##### [Partial Differential Calculas Slope = -2/n*sum(X-(Y-Y_Pred))]
#         ##### [Partial Differential Calculas Intercept = -2/n*sum(Y-Y_Pred)]
# #### Step 6: Calculate the new Slope and Intercept values [New_Slope = Old_slope - LearningRate*Delta_Slope]
# #### Step 7: Print the Final Values of M and C

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Laxminarayen/Inceptez-Batch-17/main/Day%205%20Linear%20Regression%20Hands%20on/data.csv")
df
# Out:
#     32.502345269453031  31.70700584656992
# 0            53.426804          68.777596
# 1            61.530358          62.562382
# 2            47.475640          71.546632
# 3            59.813208          87.230925
# 4            55.142188          78.211518
# ..                 ...                ...
# 94           50.030174          81.536991
# 95           49.239765          72.111832
# 96           50.039576          85.232007
# 97           48.149859          66.224958
# 98           25.128485          53.454394
#
# [99 rows x 2 columns]

# %%
X= df.iloc[:,0]
Y= df.iloc[:,1]
plt.scatter(X,Y)
#plt.plot([min(X),max(X)],[min(Y),max(Y)],color = 'red')
plt.show()

# %%
m=0
c=0
Y_pred = m*X+c
plt.scatter(X,Y)
plt.plot([min(X),max(X)],[min(Y_pred),max(Y_pred)],color = 'red')
plt.show()

# %%
L = 0.0001
iter_ = 1000

n = float(len(X))

#For loop - Performing Gradient Descent 
for i in range(iter_):
    Y_pred = (m*X)+c #The current prediction value 
    D_m = (-2/n)*sum(X * (Y - Y_pred)) #Delta Slope
    D_c = (-2/n)*sum(Y - Y_pred) #Delta Intercept
    
    m = m - (L*D_m) 
    c = c - (L*D_c)
     
    print("The Slope and intercept for iteration:",i+1)
    print("Slope: ",m)
    print("Intercept: ",c)

print("After 1000 iterations values of slope: %0.2f and intercept: %0.2f " %(m,c))
# Out:
# The Slope and intercept for iteration: 1
# Slope:  0.7424335285415494
# Intercept:  0.014629895049539552
# The Slope and intercept for iteration: 2
# Slope:  1.1126970531564835
# Intercept:  0.02196251949501772
# The Slope and intercept for iteration: 3
# Slope:  1.2973530613136097
# Intercept:  0.02565587059950957
# The Slope and intercept for iteration: 4
# Slope:  1.3894434413943608
# Intercept:  0.027534253868739502
# The Slope and intercept for iteration: 5
# Slope:  1.4353697670003447
# Intercept:  0.028507481513835913
# The Slope and intercept for iteration: 6
# Slope:  1.4582732927875135
# Intercept:  0.02902929237235795
# The Slope and intercept for iteration: 7
# Slope:  1.4696949563897819
# Intercept:  0.029325973726661497
# The Slope and intercept for iteration: 8
# Slope:  1.4753904198682661
# Intercept:  0.02951037889658117
# The Slope and intercept for iteration: 9
# Slope:  1.478230129872329
# Intercept:  0.029638789753839184
# ...

# %%
plt.scatter(X,Y)
plt.plot([min(X),max(X)],[min(Y_pred),max(Y_pred)],color = 'red')
plt.show()
